# %%
# Raport: Përdorimi i Git dhe GitHub

## Emri: Gledis Halilaj   
## Data: 22-04-2026

# %%
## 1. Qëllimi i ushtrimit
Qëllimi i këtij ushtrimi ishte të njihemi me sistemin e kontrollit të versioneve Git dhe platformën GitHub, si dhe të mësojmë komandat bazë për menaxhimin e projekteve.

# %%
## 2. Përshkrimi i Git dhe GitHub
Git është një sistem për kontrollin e versioneve që lejon ruajtjen dhe menaxhimin e ndryshimeve në kod.

GitHub është një platformë online që përdoret për ruajtjen dhe shpërndarjen e projekteve që përdorin Git.

# %%
## 3. Inicializimi i një repository
Për të filluar një projekt të ri përdorim komandën:

# %%
# !git init

# %%
Kjo komandë krijon një repository të ri lokal ku do të ruhen ndryshimet e projektit.

# %%
# !git status

# %%
Komanda git status tregon gjendjen aktuale të skedarëve në projekt.

# %%
Komanda git status tregon gjendjen aktuale të skedarëve në projekt.

# %%
# !git add .

# %%
Kjo komandë shton të gjithë skedarët në staging area.
