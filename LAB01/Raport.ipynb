# %% [markdown]
# # Raport: LAB01 - Conda dhe Jupyter Notebook
#
# ## Emri: Gledis Halilaj
# ## Data: 22-04-2026

# %% [markdown]
# ## 1. Qëllimi i laboratorit
#
# Qëllimi i këtij laboratori është ngritja e mjedisit bazë të punës për raportet laboratorike. Kërkesat kryesore janë:
#
# - të kuptohet roli i Conda/Miniconda për menaxhimin e paketave dhe mjediseve;
# - të krijohet një environment i izoluar për kursin;
# - të instalohen paketat shkencore `numpy`, `scipy`, `pandas`, `matplotlib` dhe `jupyterlab`;
# - të hapet JupyterLab dhe të krijohet notebook-u i raportit;
# - të përdoren qeliza Markdown për tekstin dhe qeliza Code për llogaritjet.

# %% [markdown]
# ## 2. Mjedisi i punës me Conda
#
# Conda përdoret sepse mban projektet të ndara nga njëri-tjetri. Një environment ka versionin e vet të Python-it dhe paketat e veta, prandaj raportet laboratorike bëhen më të riprodhueshme.
#
# Workflow i përdorur:
#
# ```bash
# conda create -n intro-lab python=3.11 numpy scipy pandas matplotlib jupyterlab
# conda activate intro-lab
# jupyter lab
# ```
#
# Nëse environment nuk është aktiv, komandat dhe paketat mund të ekzekutohen në një Python tjetër nga ai i projektit.

# %% [markdown]
# ## 3. Struktura e notebook-ut
#
# Një raport laboratorik në Jupyter duhet të kombinojë:
#
# | Lloji i qelizës | Përdorimi |
# | --- | --- |
# | Markdown | qëllimi, teoria, metoda, diskutimi dhe përfundimi |
# | Code | llogaritjet, grafiqet dhe analiza numerike |
#
# Struktura minimale është: titulli, objektivi, teoria/metoda, analiza e të dhënave, rezultatet dhe përfundimi.

# %%
print("Përshëndetje nga JupyterLab!")

a = 5
b = 3
print("Shuma është:", a + b)

# %% [markdown]
# ## 4. Rezultatet
#
# U dokumentua workflow-i bazë për krijimin e environment-it `intro-lab`, instalimin e paketave shkencore dhe nisjen e JupyterLab. Notebook-u demonstron përdorimin e një qelize Code për të ekzekutuar komanda të thjeshta Python dhe qeliza Markdown për raportim.

# %% [markdown]
# ## 5. Përfundim
#
# LAB01 vendos bazën teknike për gjithë laboratorët e tjerë: environment i kontrolluar, notebook i organizuar dhe raport i riprodhueshëm. Conda shmang konfliktet midis paketave, ndërsa Jupyter lejon që teoria, kodi, rezultatet dhe diskutimi të ruhen në të njëjtin dokument.
