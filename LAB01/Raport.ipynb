# %%
# Raport: Hyrje në JupyterLab dhe mjedisin e punës

## Emri: _Gledis Halilaj_________  
## Data: 22-04-2026_

# %%
## 1. Qëllimi i ushtrimit
Qëllimi i këtij ushtrimi ishte të njihemi me mjedisin e JupyterLab, krijimin e notebook-ve, përdorimin e qelizave Code dhe Markdown, si dhe ekzekutimin e kodeve të thjeshta në Python.

# %%
## 2. Përshkrimi i mjedisit të punës
JupyterLab është një mjedis interaktiv që përdoret për programim dhe analizë të të dhënave. Ai përbëhet nga:
- File Browser (menaxhimi i skedarëve)
- Launcher (krijimi i dokumenteve të reja)
- Notebook (zona e punës)
# Out:
#   Cell In[1], line 2
#     JupyterLab është një mjedis interaktiv që përdoret për programim dhe analizë të të dhënave. Ai përbëhet nga:
#                ^
# SyntaxError: invalid syntax

# %%
## 2. Përshkrimi i mjedisit të punës
JupyterLab është një mjedis interaktiv që përdoret për programim dhe analizë të të dhënave. Ai përbëhet nga:
- File Browser (menaxhimi i skedarëve)
- Launcher (krijimi i dokumenteve të reja)
- Notebook (zona e punës)

# %%
## 3. Krijimi i Notebook-ut
U krijua një notebook i ri me Python dhe u ruajt me emrin:
**hyrje_jupyter.ipynb**

# %%
print("Përshëndetje nga JupyterLab!")

# %%
Ky kod shfaq një mesazh të thjeshtë në ekran dhe tregon mënyrën bazë të ekzekutimit të komandave në JupyterLab.

# %%
a = 5
b = 3
print("Shuma është:", a + b)
